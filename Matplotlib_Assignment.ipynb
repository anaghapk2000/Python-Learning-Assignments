# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([2,4,6,8],[10,20,30,40])
plt.xlabel("time")
plt.ylabel("velocity")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[2,4,9,16],'g--')
plt.plot([5,6,7,8],[7,11,15,18],'rs')
plt.xlabel("F")
plt.ylabel("V")
plt.axis([0,10,0,20])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,15,1)
plt.plot(x,x,'r--',x,x*2,'gs',x,x*3,'y^',x*4,'bo')
plt.show()

# %%
 def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
# Out:
# [<matplotlib.lines.Line2D at 0x7f799d22f810>,
#  <matplotlib.lines.Line2D at 0x7f799d22fa50>]
